# %%
# Import needed modules (needs yt>=4 version, do pip install 'yt>=4.0' if needed)
# Classical yt plot examples can be found in Cookbook https://yt-project.org/doc/cookbook
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset
yt.set_log_level(0)

# %%
# Set working directory
pathname = '/home/marm/Desktop/gempic/build'
pathname_out = pathname + '/processed'
try:
    os.mkdir(pathname_out)
except(FileExistsError):
    pass
os.chdir(pathname)
sim_name = "rho"

# %%
# Read data
slices =os.listdir("Plotfiles")
slices.sort()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 1)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 1000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 5000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 10000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 20000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 30000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
 pplotfile = './Plotfiles/{}{:05d}'.format(sim_name, 40000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()

# %%
plotfile = './Plotfiles/{}{:05d}'.format(sim_name, 50000)
ds = yt.load(plotfile)
field_data = ds.covering_grid(0, ds.domain_left_edge, ds.domain_dimensions)
rho = field_data['boxlib', 'rho']
plt.plot((rho)[:,0,0])
plt.show()
